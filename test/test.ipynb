# %%
import pandas as pd

df = pd.read_csv("backend-project/airflow/data/raw/nasa_power_data.csv")
df.to_parquet("backend-project/airflow/data/raw/power_daily1.parquet")

# %%
import pandas as pd

df = pd.read_csv("nasa_power_data.csv")
df
# Out:
#              DATE  AIRMASS  ALLSKY_KT  ALLSKY_NKT  ALLSKY_SFC_LW_DWN  \
# 0      1981-01-01   -999.0     -999.0      -999.0             -999.0
# 1      1981-01-02   -999.0     -999.0      -999.0             -999.0
# 2      1981-01-03   -999.0     -999.0      -999.0             -999.0
# 3      1981-01-04   -999.0     -999.0      -999.0             -999.0
# 4      1981-01-05   -999.0     -999.0      -999.0             -999.0
# ...           ...      ...        ...         ...                ...
# 16394  2025-11-20   -999.0     -999.0      -999.0             -999.0
# 16395  2025-11-21   -999.0     -999.0      -999.0             -999.0
# 16396  2025-11-22   -999.0     -999.0      -999.0             -999.0
# 16397  2025-11-23   -999.0     -999.0      -999.0             -999.0
# 16398  2025-11-24   -999.0     -999.0      -999.0             -999.0
#
#        ALLSKY_SFC_LW_UP  ALLSKY_SFC_PAR_DIFF  ALLSKY_SFC_PAR_DIRH  \
# 0                -999.0               -999.0               -999.0
# ...

# %%
import pandas as pd

df = pd.read_csv("feature_engineering_t2m_output.csv")
df.shape

# %%
df
# Out:
#              date  tsoil1  tsoil2  tsoil3  tsoil4    t2m  t2m_max  t2m_min  \
# 0      1981-01-08   28.31   27.46   26.51   26.12  27.44    32.15    23.01
# 1      1981-01-09   27.89   27.60   26.72   26.17  26.87    32.18    22.54
# 2      1981-01-10   26.91   27.15   26.81   26.22  26.14    32.43    20.14
# 3      1981-01-11   25.44   26.53   26.76   26.27  23.96    29.28    19.07
# 4      1981-01-12   23.70   25.34   26.51   26.31  21.98    27.99    16.64
# ...           ...     ...     ...     ...     ...    ...      ...      ...
# 16384  2025-11-17   24.51   25.08   25.84   26.55  24.91    26.56    23.22
# 16385  2025-11-18   24.79   25.09   25.70   26.49  25.29    27.60    23.94
# 16386  2025-11-19   22.18   24.21   25.55   26.42  21.88    23.97    19.08
# 16387  2025-11-20   19.76   22.13   24.89   26.32  19.72    21.68    17.56
# 16388  2025-11-21   20.52   21.67   24.13   26.16  21.27    24.34    18.43
#
# ...
