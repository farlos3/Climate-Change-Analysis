# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Dataset/nasa_power_prepared_data.csv')

# %%
df.head(3)
# Out:
#          date  evland  evptrns  gwetprof  gwetroot  gwettop  hdd0  hdd10  \
# 0  1981-01-01    1.88     0.34      0.61      0.61     0.62   0.0    0.0
# 1  1981-01-02    1.77     0.28      0.61      0.60     0.62   0.0    0.0
# 2  1981-01-03    1.72     0.24      0.60      0.60     0.62   0.0    0.0
#
#    hdd18_3  pbltop  ...  soil_d5_forecast  soil_d6_forecast  soil_d7_forecast  \
# 0      0.0   93.03  ...              0.59              0.58              0.56
# 1      0.0   91.99  ...              0.58              0.56              0.55
# 2      0.0   91.67  ...              0.56              0.55              0.54
#
#    wind_d1_forecast  wind_d2_forecast  wind_d3_forecast  wind_d4_forecast  \
# 0              3.09              3.83              3.09              1.75
# 1              3.83              3.09              1.75              2.36
# 2              3.09              1.75              2.36              2.64
#
#    wind_d5_forecast  wind_d6_forecast  wind_d7_forecast
# 0              2.36              2.64              1.95
# 1              2.64              1.95              2.52
# 2              1.95              2.52              3.58
#
# [3 rows x 107 columns]

# %% [markdown]
# ## Feature selection

# %%
df = df.sort_values("date")

# %%
COLS_TO_DROP_PRE_TRAIN = ["date", "day", "week", "weekday"]

H = 7

t2m_targets = [f"t2m_d{h}_forecast" for h in range(1, H+1)]
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
feature_cols = [col for col in num_cols if col not in t2m_targets]

# %%
selected_features = [

    # Atmospheric moisture
    "tqv", "qv2m", "qv10m", "rh2m", "t2mdew", "t2mwet",

    # Temperature variability
    "t2m_range", "t10m_range", "ts_range",

    # Pressure
    "ps", "slp",

    # Soil moisture 
    "gwettop", "gwetroot", "gwetprof",

    # Evapotranspiration / evaporation
    "evland", "evptrns", "et_total",

    # Windation 
    "u10m", "v10m", "wd10m",

    # Physical/Upper atmosphere
    "to3",

    # Rain history)
    "prectotcorr",

    # Seasonal
    "month", "season_num"
]

# %%
base_features = [c for c in selected_features if c in df.columns]
df_sel = df[["date"] + base_features + t2m_targets].copy()

# %%
df_sel
# Out:
#              date    tqv   qv2m  qv10m   rh2m  t2mdew  t2mwet  t2m_range  \
# 0      1981-01-01  30.93  12.74  12.17  66.26   17.86   21.54      11.36
# 1      1981-01-02  37.93  13.47  12.90  68.24   18.74   22.14      11.10
# 2      1981-01-03  35.02  13.45  12.98  68.62   18.74   22.08      10.14
# 3      1981-01-04  35.38  13.57  12.99  68.48   18.88   22.25      10.77
# 4      1981-01-05  35.04  13.93  13.18  66.41   19.27   22.93      10.25
# ...           ...    ...    ...    ...    ...     ...     ...        ...
# 16380  2025-11-06  58.03  18.52  17.99  87.61   23.89   25.02       6.01
# 16381  2025-11-07  53.62  19.20  18.76  89.28   24.47   25.44       3.25
# 16382  2025-11-08  61.09  19.00  18.45  84.64   24.34   25.75       4.24
# 16383  2025-11-09  59.55  19.60  18.95  84.44   24.87   26.33       5.34
# 16384  2025-11-10  59.43  19.78  19.13  84.18   25.02   26.49       4.32
#
#        t10m_range  ts_range  ...  prectotcorr  month  season_num  \
# 0           10.27     13.89  ...         0.00      1           0
# 1            9.96     13.54  ...         0.00      1           0
# 2            9.10     12.70  ...         0.00      1           0
# 3            9.92     13.60  ...         0.00      1           0
# 4            8.87     14.27  ...         0.00      1           0
# ...           ...       ...  ...          ...    ...         ...
# 16380        5.82      6.73  ...         6.95     11           2
# 16381        3.17      3.24  ...         3.06     11           2
# 16382        3.75      5.77  ...         6.95     11           2
# 16383        4.88      7.37  ...         4.94     11           2
# 16384        3.64      6.05  ...         5.61     11           2
#
#        t2m_d1_forecast  t2m_d2_forecast  t2m_d3_forecast  t2m_d4_forecast  \
# 0                25.53            25.43            25.61            26.59
# 1                25.43            25.61            26.59            26.70
# 2                25.61            26.59            26.70            26.66
# 3                26.59            26.70            26.66            27.44
# 4                26.70            26.66            27.44            26.87
# ...                ...              ...              ...              ...
# 16380            26.40            27.16            27.78            27.96
# 16381            27.16            27.78            27.96            27.73
# 16382            27.78            27.96            27.73            28.32
# 16383            27.96            27.73            28.32            27.32
# 16384            27.73            28.32            27.32            25.75
#
#        t2m_d5_forecast  t2m_d6_forecast  t2m_d7_forecast
# 0                26.70            26.66            27.44
# 1                26.66            27.44            26.87
# 2                27.44            26.87            26.14
# 3                26.87            26.14            23.96
# 4                26.14            23.96            21.98
# ...                ...              ...              ...
# 16380            27.73            28.32            27.32
# 16381            28.32            27.32            25.75
# 16382            27.32            25.75            24.49
# 16383            25.75            24.49            25.14
# 16384            24.49            25.14            24.91
#
# [16385 rows x 32 columns]

# %% [markdown]
# ### Seasonal Features

# %%
# Seasonal Features (from date/month/dayofyear)
df_sel["date"] = pd.to_datetime(df_sel["date"])
df_sel["dayofyear"] = df_sel["date"].dt.dayofyear

seasonal_df = pd.DataFrame({
    "month_sin": np.sin(2*np.pi*df_sel["month"]/12),
    "month_cos": np.cos(2*np.pi*df_sel["month"]/12),
    "doy_sin": np.sin(2*np.pi*df_sel["dayofyear"]/365),
    "doy_cos": np.cos(2*np.pi*df_sel["dayofyear"]/365),
})

# %%
df_sel.columns
# Out:
# Index(['date', 'tqv', 'qv2m', 'qv10m', 'rh2m', 't2mdew', 't2mwet', 't2m_range',
#        't10m_range', 'ts_range', 'ps', 'slp', 'gwettop', 'gwetroot',
#        'gwetprof', 'evland', 'evptrns', 'et_total', 'u10m', 'v10m', 'wd10m',
#        'to3', 'prectotcorr', 'month', 'season_num', 't2m_d1_forecast',
#        't2m_d2_forecast', 't2m_d3_forecast', 't2m_d4_forecast',
#        't2m_d5_forecast', 't2m_d6_forecast', 't2m_d7_forecast', 'dayofyear'],
#       dtype='object')

# %%
df_sel.head(3)
# Out:
#         date    tqv   qv2m  qv10m   rh2m  t2mdew  t2mwet  t2m_range  \
# 0 1981-01-01  30.93  12.74  12.17  66.26   17.86   21.54      11.36
# 1 1981-01-02  37.93  13.47  12.90  68.24   18.74   22.14      11.10
# 2 1981-01-03  35.02  13.45  12.98  68.62   18.74   22.08      10.14
#
#    t10m_range  ts_range  ...  month  season_num  t2m_d1_forecast  \
# 0       10.27     13.89  ...      1           0            25.53
# 1        9.96     13.54  ...      1           0            25.43
# 2        9.10     12.70  ...      1           0            25.61
#
#    t2m_d2_forecast  t2m_d3_forecast  t2m_d4_forecast  t2m_d5_forecast  \
# 0            25.43            25.61            26.59            26.70
# 1            25.61            26.59            26.70            26.66
# 2            26.59            26.70            26.66            27.44
#
#    t2m_d6_forecast  t2m_d7_forecast  dayofyear
# 0            26.66            27.44          1
# 1            27.44            26.87          2
# 2            26.87            26.14          3
#
# [3 rows x 33 columns]

# %% [markdown]
# ### Lag Features

# %%
# Lag Features
lags = [1, 3, 7] # lag 1, 3, 7 days
lag_frames = [] 

for col in base_features:
    if col == "month":
        continue
    for lag in lags:
        lag_frames.append(
            df_sel[col].shift(lag).rename(f"{col}_lag{lag}")
        )
        
lag_df = pd.concat(lag_frames, axis=1)

# %%
df_sel.columns
# Out:
# Index(['date', 'tqv', 'qv2m', 'qv10m', 'rh2m', 't2mdew', 't2mwet', 't2m_range',
#        't10m_range', 'ts_range', 'ps', 'slp', 'gwettop', 'gwetroot',
#        'gwetprof', 'evland', 'evptrns', 'et_total', 'u10m', 'v10m', 'wd10m',
#        'to3', 'prectotcorr', 'month', 'season_num', 't2m_d1_forecast',
#        't2m_d2_forecast', 't2m_d3_forecast', 't2m_d4_forecast',
#        't2m_d5_forecast', 't2m_d6_forecast', 't2m_d7_forecast', 'dayofyear'],
#       dtype='object')

# %% [markdown]
# ### Rolling Features

# %%
# Rolling Window Features for Rain Forecasting
rolling_cols = [
    "qv2m", "qv10m", "tqv",
    "rh2m", "t2mdew", "t2mwet",
    "ps", "slp",
    "gwettop", "gwetroot"
]

windows = [3, 7]

rolling_frames = []
for col in rolling_cols:
    for w in windows:
        rolling_frames.append(
            df_sel[col].rolling(w).mean().rename(f"{col}_roll{w}_mean")
        )
        rolling_frames.append(
            df_sel[col].rolling(w).std().rename(f"{col}_roll{w}_std")
        )

rolling_df = pd.concat(rolling_frames, axis=1)

# %%
df_fe = pd.concat([
    df_sel,
    seasonal_df,
    lag_df,
    rolling_df
], axis=1)

df_fe = df_fe.dropna().reset_index(drop=True)

print("Final FE shape:", df_fe.shape)
# Out:
# Final FE shape: (16378, 146)

# %%
df_fe.to_csv('../Dataset/FeatureEngineering_rain_data.csv', index=False)

# %%
df_fe.columns.tolist()
# Out:
# ['date',
#  'tqv',
#  'qv2m',
#  'qv10m',
#  'rh2m',
#  't2mdew',
#  't2mwet',
#  't2m_range',
#  't10m_range',
#  'ts_range',
#  'ps',
#  'slp',
#  'gwettop',
#  'gwetroot',
#  'gwetprof',
#  'evland',
#  'evptrns',
#  'et_total',
#  'u10m',
#  'v10m',
#  'wd10m',
#  'to3',
#  'prectotcorr',
#  'month',
#  'season_num',
#  't2m_d1_forecast',
#  't2m_d2_forecast',
#  't2m_d3_forecast',
#  't2m_d4_forecast',
#  't2m_d5_forecast',
#  't2m_d6_forecast',
#  't2m_d7_forecast',
#  'dayofyear',
#  'month_sin',
#  'month_cos',
#  'doy_sin',
#  'doy_cos',
#  'tqv_lag1',
#  'tqv_lag3',
#  'tqv_lag7',
#  'qv2m_lag1',
#  'qv2m_lag3',
#  'qv2m_lag7',
#  'qv10m_lag1',
#  'qv10m_lag3',
#  'qv10m_lag7',
#  'rh2m_lag1',
#  'rh2m_lag3',
#  'rh2m_lag7',
#  't2mdew_lag1',
#  't2mdew_lag3',
#  't2mdew_lag7',
#  't2mwet_lag1',
#  't2mwet_lag3',
#  't2mwet_lag7',
#  't2m_range_lag1',
#  't2m_range_lag3',
#  't2m_range_lag7',
#  't10m_range_lag1',
#  't10m_range_lag3',
#  't10m_range_lag7',
#  'ts_range_lag1',
#  'ts_range_lag3',
#  'ts_range_lag7',
#  'ps_lag1',
#  'ps_lag3',
#  'ps_lag7',
#  'slp_lag1',
#  'slp_lag3',
#  'slp_lag7',
#  'gwettop_lag1',
#  'gwettop_lag3',
#  'gwettop_lag7',
#  'gwetroot_lag1',
#  'gwetroot_lag3',
#  'gwetroot_lag7',
#  'gwetprof_lag1',
#  'gwetprof_lag3',
#  'gwetprof_lag7',
#  'evland_lag1',
#  'evland_lag3',
#  'evland_lag7',
#  'evptrns_lag1',
#  'evptrns_lag3',
#  'evptrns_lag7',
#  'et_total_lag1',
#  'et_total_lag3',
#  'et_total_lag7',
#  'u10m_lag1',
#  'u10m_lag3',
#  'u10m_lag7',
#  'v10m_lag1',
#  'v10m_lag3',
#  'v10m_lag7',
#  'wd10m_lag1',
#  'wd10m_lag3',
#  'wd10m_lag7',
#  'to3_lag1',
#  'to3_lag3',
#  'to3_lag7',
#  'prectotcorr_lag1',
#  'prectotcorr_lag3',
#  'prectotcorr_lag7',
#  'season_num_lag1',
#  'season_num_lag3',
#  'season_num_lag7',
#  'qv2m_roll3_mean',
#  'qv2m_roll3_std',
#  'qv2m_roll7_mean',
#  'qv2m_roll7_std',
#  'qv10m_roll3_mean',
#  'qv10m_roll3_std',
#  'qv10m_roll7_mean',
#  'qv10m_roll7_std',
#  'tqv_roll3_mean',
#  'tqv_roll3_std',
#  'tqv_roll7_mean',
#  'tqv_roll7_std',
#  'rh2m_roll3_mean',
#  'rh2m_roll3_std',
#  'rh2m_roll7_mean',
#  'rh2m_roll7_std',
#  't2mdew_roll3_mean',
#  't2mdew_roll3_std',
#  't2mdew_roll7_mean',
#  't2mdew_roll7_std',
#  't2mwet_roll3_mean',
#  't2mwet_roll3_std',
#  't2mwet_roll7_mean',
#  't2mwet_roll7_std',
#  'ps_roll3_mean',
#  'ps_roll3_std',
#  'ps_roll7_mean',
#  'ps_roll7_std',
#  'slp_roll3_mean',
#  'slp_roll3_std',
#  'slp_roll7_mean',
#  'slp_roll7_std',
#  'gwettop_roll3_mean',
#  'gwettop_roll3_std',
#  'gwettop_roll7_mean',
#  'gwettop_roll7_std',
#  'gwetroot_roll3_mean',
#  'gwetroot_roll3_std',
#  'gwetroot_roll7_mean',
#  'gwetroot_roll7_std']
