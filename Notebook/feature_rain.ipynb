# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Dataset/nasa_power_prepared_data.csv')

# %%
df.tail(3)
# Out:
#              date  evland  evptrns  gwetprof  gwetroot  gwettop  hdd0  hdd10  \
# 16386  2025-11-12    3.96     2.46      0.92      0.94     0.92   0.0    0.0
# 16387  2025-11-13    2.83     1.06      0.92      0.94     0.92   0.0    0.0
# 16388  2025-11-14    4.90     1.66      0.92      0.94     0.91   0.0    0.0
#
#        hdd18_3    pbltop  ...  soil_d5_forecast  soil_d6_forecast  \
# 16386      0.0  92.68754  ...              0.91              0.92
# 16387      0.0  92.68754  ...              0.92              0.91
# 16388      0.0  92.68754  ...              0.91              0.90
#
#        soil_d7_forecast  wind_d1_forecast  wind_d2_forecast  wind_d3_forecast  \
# 16386              0.91              1.80              3.70              4.17
# 16387              0.90              3.70              4.17              4.63
# 16388              0.89              4.17              4.63              4.17
#
#        wind_d4_forecast  wind_d5_forecast  wind_d6_forecast  wind_d7_forecast
# 16386              4.63              4.17              4.89              6.46
# 16387              4.17              4.89              6.46              5.80
# 16388              4.89              6.46              5.80              5.23
#
# [3 rows x 107 columns]

# %% [markdown]
# ## Feature selection

# %%
df = df.sort_values("date")

# %%
COLS_TO_DROP_PRE_TRAIN = ["date", "day", "week", "weekday"]

H = 7

t2m_targets = [f"t2m_d{h}_forecast" for h in range(1, H+1)]
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
feature_cols = [col for col in num_cols if col not in t2m_targets]

# %%
selected_features = [

    # Atmospheric moisture
    "tqv", "qv2m", "qv10m", "rh2m", "t2mdew", "t2mwet",

    # Temperature variability
    "t2m_range", "t10m_range", "ts_range",

    # Pressure
    "ps", "slp",

    # Soil moisture 
    "gwettop", "gwetroot", "gwetprof",

    # Evapotranspiration / evaporation
    "evland", "evptrns", "et_total",

    # Windation 
    "u10m", "v10m", "wd10m",

    # Physical/Upper atmosphere
    "to3",

    # Rain history)
    "prectotcorr",

    # Seasonal
    "month", "season_num"
]

# %%
base_features = [c for c in selected_features if c in df.columns]
df_sel = df[["date"] + base_features + t2m_targets].copy()

# %%
df_sel
# Out:
#              date    tqv   qv2m  qv10m   rh2m  t2mdew  t2mwet  t2m_range  \
# 0      1981-01-01  30.93  12.74  12.17  66.26   17.86   21.54      11.36
# 1      1981-01-02  37.93  13.47  12.90  68.24   18.74   22.14      11.10
# 2      1981-01-03  35.02  13.45  12.98  68.62   18.74   22.08      10.14
# 3      1981-01-04  35.38  13.57  12.99  68.48   18.88   22.25      10.77
# 4      1981-01-05  35.04  13.93  13.18  66.41   19.27   22.93      10.25
# ...           ...    ...    ...    ...    ...     ...     ...        ...
# 16384  2025-11-10  59.43  19.78  19.13  84.18   25.02   26.49       4.32
# 16385  2025-11-11  58.11  19.58  18.98  84.54   24.85   26.29       5.11
# 16386  2025-11-12  56.73  19.05  18.19  79.64   24.43   26.38       5.26
# 16387  2025-11-13  62.02  19.66  19.16  86.97   24.95   26.13       3.48
# 16388  2025-11-14  47.05  17.28  16.65  84.19   22.83   24.29       4.48
#
#        t10m_range  ts_range  ...  prectotcorr  month  season_num  \
# 0           10.27     13.89  ...         0.00      1           0
# 1            9.96     13.54  ...         0.00      1           0
# 2            9.10     12.70  ...         0.00      1           0
# 3            9.92     13.60  ...         0.00      1           0
# 4            8.87     14.27  ...         0.00      1           0
# ...           ...       ...  ...          ...    ...         ...
# 16384        3.64      6.05  ...         5.61     11           2
# 16385        4.79      6.04  ...         6.32     11           2
# 16386        4.69      7.46  ...         6.14     11           2
# 16387        3.29      3.91  ...        11.61     11           2
# 16388        4.21      4.86  ...         1.93     11           2
#
#        t2m_d1_forecast  t2m_d2_forecast  t2m_d3_forecast  t2m_d4_forecast  \
# 0                25.53            25.43            25.61            26.59
# 1                25.43            25.61            26.59            26.70
# 2                25.61            26.59            26.70            26.66
# 3                26.59            26.70            26.66            27.44
# 4                26.70            26.66            27.44            26.87
# ...                ...              ...              ...              ...
# 16384            27.73            28.32            27.32            25.75
# 16385            28.32            27.32            25.75            24.49
# 16386            27.32            25.75            24.49            25.14
# 16387            25.75            24.49            25.14            24.91
# 16388            24.49            25.14            24.91            25.29
#
#        t2m_d5_forecast  t2m_d6_forecast  t2m_d7_forecast
# 0                26.70            26.66            27.44
# 1                26.66            27.44            26.87
# 2                27.44            26.87            26.14
# 3                26.87            26.14            23.96
# 4                26.14            23.96            21.98
# ...                ...              ...              ...
# 16384            24.49            25.14            24.91
# 16385            25.14            24.91            25.29
# 16386            24.91            25.29            21.88
# 16387            25.29            21.88            19.72
# 16388            21.88            19.72            21.27
#
# [16389 rows x 32 columns]

# %% [markdown]
# ### Seasonal Features

# %%
# Seasonal Features (from date/month/dayofyear)
df_sel["date"] = pd.to_datetime(df_sel["date"])
df_sel["dayofyear"] = df_sel["date"].dt.dayofyear

seasonal_df = pd.DataFrame({
    "month_sin": np.sin(2*np.pi*df_sel["month"]/12),
    "month_cos": np.cos(2*np.pi*df_sel["month"]/12),
    "doy_sin": np.sin(2*np.pi*df_sel["dayofyear"]/365),
    "doy_cos": np.cos(2*np.pi*df_sel["dayofyear"]/365),
})

# %%
df_sel.columns
# Out:
# Index(['date', 'tqv', 'qv2m', 'qv10m', 'rh2m', 't2mdew', 't2mwet', 't2m_range',
#        't10m_range', 'ts_range', 'ps', 'slp', 'gwettop', 'gwetroot',
#        'gwetprof', 'evland', 'evptrns', 'et_total', 'u10m', 'v10m', 'wd10m',
#        'to3', 'prectotcorr', 'month', 'season_num', 't2m_d1_forecast',
#        't2m_d2_forecast', 't2m_d3_forecast', 't2m_d4_forecast',
#        't2m_d5_forecast', 't2m_d6_forecast', 't2m_d7_forecast', 'dayofyear'],
#       dtype='object')

# %%
df_sel.head(3)
# Out:
#         date    tqv   qv2m  qv10m   rh2m  t2mdew  t2mwet  t2m_range  \
# 0 1981-01-01  30.93  12.74  12.17  66.26   17.86   21.54      11.36
# 1 1981-01-02  37.93  13.47  12.90  68.24   18.74   22.14      11.10
# 2 1981-01-03  35.02  13.45  12.98  68.62   18.74   22.08      10.14
#
#    t10m_range  ts_range  ...  month  season_num  t2m_d1_forecast  \
# 0       10.27     13.89  ...      1           0            25.53
# 1        9.96     13.54  ...      1           0            25.43
# 2        9.10     12.70  ...      1           0            25.61
#
#    t2m_d2_forecast  t2m_d3_forecast  t2m_d4_forecast  t2m_d5_forecast  \
# 0            25.43            25.61            26.59            26.70
# 1            25.61            26.59            26.70            26.66
# 2            26.59            26.70            26.66            27.44
#
#    t2m_d6_forecast  t2m_d7_forecast  dayofyear
# 0            26.66            27.44          1
# 1            27.44            26.87          2
# 2            26.87            26.14          3
#
# [3 rows x 33 columns]

# %% [markdown]
# ### Lag Features

# %%
# Lag Features
lags = [1, 3, 7] # lag 1, 3, 7 days
lag_frames = [] 

for col in base_features:
    if col == "month":
        continue
    for lag in lags:
        lag_frames.append(
            df_sel[col].shift(lag).rename(f"{col}_lag{lag}")
        )
        
lag_df = pd.concat(lag_frames, axis=1)

# %%
df_sel.columns
# Out:
# Index(['date', 'tqv', 'qv2m', 'qv10m', 'rh2m', 't2mdew', 't2mwet', 't2m_range',
#        't10m_range', 'ts_range', 'ps', 'slp', 'gwettop', 'gwetroot',
#        'gwetprof', 'evland', 'evptrns', 'et_total', 'u10m', 'v10m', 'wd10m',
#        'to3', 'prectotcorr', 'month', 'season_num', 't2m_d1_forecast',
#        't2m_d2_forecast', 't2m_d3_forecast', 't2m_d4_forecast',
#        't2m_d5_forecast', 't2m_d6_forecast', 't2m_d7_forecast', 'dayofyear'],
#       dtype='object')

# %% [markdown]
# ### Rolling Features

# %%
# Rolling Window Features for Rain Forecasting
rolling_cols = [
    "qv2m", "qv10m", "tqv",
    "rh2m", "t2mdew", "t2mwet",
    "ps", "slp",
    "gwettop", "gwetroot"
]

windows = [3, 7]

rolling_frames = []
for col in rolling_cols:
    for w in windows:
        rolling_frames.append(
            df_sel[col].rolling(w).mean().rename(f"{col}_roll{w}_mean")
        )
        rolling_frames.append(
            df_sel[col].rolling(w).std().rename(f"{col}_roll{w}_std")
        )

rolling_df = pd.concat(rolling_frames, axis=1)

# %%
df_fe = pd.concat([
    df_sel,
    seasonal_df,
    lag_df,
    rolling_df
], axis=1)

df_fe = df_fe.dropna().reset_index(drop=True)

print("Final FE shape:", df_fe.shape)
# Out:
# Final FE shape: (16382, 146)

# %%
df_fe.to_csv('../Dataset/FeatureEngineering_rain_data.csv', index=False)
