# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Dataset/nasa_power_prepared_data.csv')

# %%
df.head(3)
# Out:
#          date  evland  evptrns  gwetprof  gwetroot  gwettop  hdd0  hdd10  \
# 0  1981-01-01    1.88     0.34      0.61      0.61     0.62   0.0    0.0
# 1  1981-01-02    1.77     0.28      0.61      0.60     0.62   0.0    0.0
# 2  1981-01-03    1.72     0.24      0.60      0.60     0.62   0.0    0.0
#
#    hdd18_3  pbltop  ...  soil_d5_forecast  soil_d6_forecast  soil_d7_forecast  \
# 0      0.0   93.03  ...              0.59              0.58              0.56
# 1      0.0   91.99  ...              0.58              0.56              0.55
# 2      0.0   91.67  ...              0.56              0.55              0.54
#
#    wind_d1_forecast  wind_d2_forecast  wind_d3_forecast  wind_d4_forecast  \
# 0              3.09              3.83              3.09              1.75
# 1              3.83              3.09              1.75              2.36
# 2              3.09              1.75              2.36              2.64
#
#    wind_d5_forecast  wind_d6_forecast  wind_d7_forecast
# 0              2.36              2.64              1.95
# 1              2.64              1.95              2.52
# 2              1.95              2.52              3.58
#
# [3 rows x 107 columns]

# %% [markdown]
# ## Feature selection

# %%
df = df.sort_values("date")

# %%
COLS_TO_DROP_PRE_TRAIN = ["date", "day", "week", "weekday"]

H = 7

t2m_targets = [f"t2m_d{h}_forecast" for h in range(1, H+1)]
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
feature_cols = [col for col in num_cols if col not in t2m_targets]

# %%
selected_features = [
    # Soil Temperature
    "tsoil1", "tsoil2", "tsoil3", "tsoil4",

    # Surface / Air Temperature
    "t2m", "t2m_max", "t2m_min",
    "t10m", "t10m_max", "t10m_min",
    "ts", "ts_min", "ts_max", "tsurf",
    "t2m_range", "t10m_range", "ts_range",

    # Wind (V component)
    "v2m", "v10m", "v50m",

    # Humidity / Air Density
    "rhoa", "t2mwet",

    # Soil Moisture
    "gwettop", "gwetroot", "gwetprof",

    # ET / Evapotranspiration
    "evptrns", "et_total", "evland",

    # Physical properties
    "z0m", "to3",

    # Seasonal (for sin/cos)
    "month",
]

# %%
base_features = [c for c in selected_features if c in df.columns]
df_sel = df[["date"] + base_features + t2m_targets].copy()

# %% [markdown]
# ### Seasonal Features

# %%
# Seasonal Features (from date/month/dayofyear)
df_sel["date"] = pd.to_datetime(df_sel["date"])
df_sel["dayofyear"] = df_sel["date"].dt.dayofyear

seasonal_df = pd.DataFrame({
    "month_sin": np.sin(2*np.pi*df_sel["month"]/12),
    "month_cos": np.cos(2*np.pi*df_sel["month"]/12),
    "doy_sin": np.sin(2*np.pi*df_sel["dayofyear"]/365),
    "doy_cos": np.cos(2*np.pi*df_sel["dayofyear"]/365),
})

# %%
df_sel.columns
# Out:
# Index(['date', 'tsoil1', 'tsoil2', 'tsoil3', 'tsoil4', 't2m', 't2m_max',
#        't2m_min', 't10m', 't10m_max', 't10m_min', 'ts', 'ts_min', 'ts_max',
#        'tsurf', 't2m_range', 't10m_range', 'ts_range', 'v2m', 'v10m', 'v50m',
#        'rhoa', 't2mwet', 'gwettop', 'gwetroot', 'gwetprof', 'evptrns',
#        'et_total', 'evland', 'z0m', 'to3', 'month', 't2m_d1_forecast',
#        't2m_d2_forecast', 't2m_d3_forecast', 't2m_d4_forecast',
#        't2m_d5_forecast', 't2m_d6_forecast', 't2m_d7_forecast', 'dayofyear'],
#       dtype='object')

# %%
df_sel.head(3)
# Out:
#         date  tsoil1  tsoil2  tsoil3  tsoil4    t2m  t2m_max  t2m_min   t10m  \
# 0 1981-01-01   25.45   25.33   25.53   26.07  25.21    31.06    19.70  25.46
# 1 1981-01-02   25.78   25.58   25.58   26.05  25.53    31.07    19.97  25.72
# 2 1981-01-03   26.05   25.85   25.67   26.04  25.43    30.87    20.73  25.44
#
#    t10m_max  ...     to3  month  t2m_d1_forecast  t2m_d2_forecast  \
# 0     30.33  ...  246.00      1            25.53            25.43
# 1     30.31  ...  244.56      1            25.43            25.61
# 2     29.92  ...  245.96      1            25.61            26.59
#
#    t2m_d3_forecast  t2m_d4_forecast  t2m_d5_forecast  t2m_d6_forecast  \
# 0            25.61            26.59            26.70            26.66
# 1            26.59            26.70            26.66            27.44
# 2            26.70            26.66            27.44            26.87
#
#    t2m_d7_forecast  dayofyear
# 0            27.44          1
# 1            26.87          2
# 2            26.14          3
#
# [3 rows x 40 columns]

# %% [markdown]
# ### Lag Features

# %%
# Lag Features
lags = [1, 3, 7] # lag 1, 3, 7 days
lag_frames = [] 

for col in base_features:
    if col == "month":
        continue
    for lag in lags:
        lag_frames.append(
            df_sel[col].shift(lag).rename(f"{col}_lag{lag}")
        )
        
lag_df = pd.concat(lag_frames, axis=1)

# %%
df_sel.columns
# Out:
# Index(['date', 'tsoil1', 'tsoil2', 'tsoil3', 'tsoil4', 't2m', 't2m_max',
#        't2m_min', 't10m', 't10m_max', 't10m_min', 'ts', 'ts_min', 'ts_max',
#        'tsurf', 't2m_range', 't10m_range', 'ts_range', 'v2m', 'v10m', 'v50m',
#        'rhoa', 't2mwet', 'gwettop', 'gwetroot', 'gwetprof', 'evptrns',
#        'et_total', 'evland', 'z0m', 'to3', 'month', 't2m_d1_forecast',
#        't2m_d2_forecast', 't2m_d3_forecast', 't2m_d4_forecast',
#        't2m_d5_forecast', 't2m_d6_forecast', 't2m_d7_forecast', 'dayofyear'],
#       dtype='object')

# %% [markdown]
# ### Rolling Features

# %%
# Rolling Window Features
rolling_cols = [
    "t2m", "t2m_max", "t2m_min",
    "t10m", "t10m_max", "t10m_min",
    "ts", "ts_max", "ts_min", "tsurf",
    "tsoil1", "tsoil2", "tsoil3", "tsoil4",
    "t2mwet", "rhoa",
    "gwettop", "gwetroot", "gwetprof",
    "v2m", "v10m", "v50m"
]

windows = [3, 7]

rolling_frames = []
for col in rolling_cols:
    for w in windows:
        rolling_frames.append(
            df_sel[col].rolling(w).mean().rename(f"{col}_roll{w}_mean")
        )
        rolling_frames.append(
            df_sel[col].rolling(w).std().rename(f"{col}_roll{w}_std")
        )

rolling_df = pd.concat(rolling_frames, axis=1)

# %%
df_fe = pd.concat([
    df_sel,
    seasonal_df,
    lag_df,
    rolling_df
], axis=1)

df_fe = df_fe.dropna().reset_index(drop=True)

print("Final FE shape:", df_fe.shape)
# Out:
# Final FE shape: (16378, 222)

# %%
df_fe.to_csv('../Dataset/FeatureEngineering_T2M_data.csv', index=False)

# %%
df_fe.columns.tolist()
# Out:
# ['date',
#  'tsoil1',
#  'tsoil2',
#  'tsoil3',
#  'tsoil4',
#  't2m',
#  't2m_max',
#  't2m_min',
#  't10m',
#  't10m_max',
#  't10m_min',
#  'ts',
#  'ts_min',
#  'ts_max',
#  'tsurf',
#  't2m_range',
#  't10m_range',
#  'ts_range',
#  'v2m',
#  'v10m',
#  'v50m',
#  'rhoa',
#  't2mwet',
#  'gwettop',
#  'gwetroot',
#  'gwetprof',
#  'evptrns',
#  'et_total',
#  'evland',
#  'z0m',
#  'to3',
#  'month',
#  't2m_d1_forecast',
#  't2m_d2_forecast',
#  't2m_d3_forecast',
#  't2m_d4_forecast',
#  't2m_d5_forecast',
#  't2m_d6_forecast',
#  't2m_d7_forecast',
#  'dayofyear',
#  'month_sin',
#  'month_cos',
#  'doy_sin',
#  'doy_cos',
#  'tsoil1_lag1',
#  'tsoil1_lag3',
#  'tsoil1_lag7',
#  'tsoil2_lag1',
#  'tsoil2_lag3',
#  'tsoil2_lag7',
#  'tsoil3_lag1',
#  'tsoil3_lag3',
#  'tsoil3_lag7',
#  'tsoil4_lag1',
#  'tsoil4_lag3',
#  'tsoil4_lag7',
#  't2m_lag1',
#  't2m_lag3',
#  't2m_lag7',
#  't2m_max_lag1',
#  't2m_max_lag3',
#  't2m_max_lag7',
#  't2m_min_lag1',
#  't2m_min_lag3',
#  't2m_min_lag7',
#  't10m_lag1',
#  't10m_lag3',
#  't10m_lag7',
#  't10m_max_lag1',
#  't10m_max_lag3',
#  't10m_max_lag7',
#  't10m_min_lag1',
#  't10m_min_lag3',
#  't10m_min_lag7',
#  'ts_lag1',
#  'ts_lag3',
#  'ts_lag7',
#  'ts_min_lag1',
#  'ts_min_lag3',
#  'ts_min_lag7',
#  'ts_max_lag1',
#  'ts_max_lag3',
#  'ts_max_lag7',
#  'tsurf_lag1',
#  'tsurf_lag3',
#  'tsurf_lag7',
#  't2m_range_lag1',
#  't2m_range_lag3',
#  't2m_range_lag7',
#  't10m_range_lag1',
#  't10m_range_lag3',
#  't10m_range_lag7',
#  'ts_range_lag1',
#  'ts_range_lag3',
#  'ts_range_lag7',
#  'v2m_lag1',
#  'v2m_lag3',
#  'v2m_lag7',
#  'v10m_lag1',
#  'v10m_lag3',
#  'v10m_lag7',
#  'v50m_lag1',
#  'v50m_lag3',
#  'v50m_lag7',
#  'rhoa_lag1',
#  'rhoa_lag3',
#  'rhoa_lag7',
#  't2mwet_lag1',
#  't2mwet_lag3',
#  't2mwet_lag7',
#  'gwettop_lag1',
#  'gwettop_lag3',
#  'gwettop_lag7',
#  'gwetroot_lag1',
#  'gwetroot_lag3',
#  'gwetroot_lag7',
#  'gwetprof_lag1',
#  'gwetprof_lag3',
#  'gwetprof_lag7',
#  'evptrns_lag1',
#  'evptrns_lag3',
#  'evptrns_lag7',
#  'et_total_lag1',
#  'et_total_lag3',
#  'et_total_lag7',
#  'evland_lag1',
#  'evland_lag3',
#  'evland_lag7',
#  'z0m_lag1',
#  'z0m_lag3',
#  'z0m_lag7',
#  'to3_lag1',
#  'to3_lag3',
#  'to3_lag7',
#  't2m_roll3_mean',
#  't2m_roll3_std',
#  't2m_roll7_mean',
#  't2m_roll7_std',
#  't2m_max_roll3_mean',
#  't2m_max_roll3_std',
#  't2m_max_roll7_mean',
#  't2m_max_roll7_std',
#  't2m_min_roll3_mean',
#  't2m_min_roll3_std',
#  't2m_min_roll7_mean',
#  't2m_min_roll7_std',
#  't10m_roll3_mean',
#  't10m_roll3_std',
#  't10m_roll7_mean',
#  't10m_roll7_std',
#  't10m_max_roll3_mean',
#  't10m_max_roll3_std',
#  't10m_max_roll7_mean',
#  't10m_max_roll7_std',
#  't10m_min_roll3_mean',
#  't10m_min_roll3_std',
#  't10m_min_roll7_mean',
#  't10m_min_roll7_std',
#  'ts_roll3_mean',
#  'ts_roll3_std',
#  'ts_roll7_mean',
#  'ts_roll7_std',
#  'ts_max_roll3_mean',
#  'ts_max_roll3_std',
#  'ts_max_roll7_mean',
#  'ts_max_roll7_std',
#  'ts_min_roll3_mean',
#  'ts_min_roll3_std',
#  'ts_min_roll7_mean',
#  'ts_min_roll7_std',
#  'tsurf_roll3_mean',
#  'tsurf_roll3_std',
#  'tsurf_roll7_mean',
#  'tsurf_roll7_std',
#  'tsoil1_roll3_mean',
#  'tsoil1_roll3_std',
#  'tsoil1_roll7_mean',
#  'tsoil1_roll7_std',
#  'tsoil2_roll3_mean',
#  'tsoil2_roll3_std',
#  'tsoil2_roll7_mean',
#  'tsoil2_roll7_std',
#  'tsoil3_roll3_mean',
#  'tsoil3_roll3_std',
#  'tsoil3_roll7_mean',
#  'tsoil3_roll7_std',
#  'tsoil4_roll3_mean',
#  'tsoil4_roll3_std',
#  'tsoil4_roll7_mean',
#  'tsoil4_roll7_std',
#  't2mwet_roll3_mean',
#  't2mwet_roll3_std',
#  't2mwet_roll7_mean',
#  't2mwet_roll7_std',
#  'rhoa_roll3_mean',
#  'rhoa_roll3_std',
#  'rhoa_roll7_mean',
#  'rhoa_roll7_std',
#  'gwettop_roll3_mean',
#  'gwettop_roll3_std',
#  'gwettop_roll7_mean',
#  'gwettop_roll7_std',
#  'gwetroot_roll3_mean',
#  'gwetroot_roll3_std',
#  'gwetroot_roll7_mean',
#  'gwetroot_roll7_std',
#  'gwetprof_roll3_mean',
#  'gwetprof_roll3_std',
#  'gwetprof_roll7_mean',
#  'gwetprof_roll7_std',
#  'v2m_roll3_mean',
#  'v2m_roll3_std',
#  'v2m_roll7_mean',
#  'v2m_roll7_std',
#  'v10m_roll3_mean',
#  'v10m_roll3_std',
#  'v10m_roll7_mean',
#  'v10m_roll7_std',
#  'v50m_roll3_mean',
#  'v50m_roll3_std',
#  'v50m_roll7_mean',
#  'v50m_roll7_std']
